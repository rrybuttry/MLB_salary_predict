# %% [markdown]
# [pybaseball](https://github.com/jldbc/pybaseball)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from pybaseball import playerid_lookup

# %%
dat = playerid_lookup('Ohtani','Shohei')
# Out:
# Gathering player lookup table. This may take a moment.

# %%
dat
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0    ohtani     shohei     660271  ohtas001  ohtansh01          19755
#
#    mlb_played_first  mlb_played_last
# 0            2018.0           2023.0

# %% [markdown]
# ``MLBAM`` is the id for statcast

# %%
playerid_lookup('harper','bryce')
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0    harper      bryce     547180  harpb003  harpebr03          11579
#
#    mlb_played_first  mlb_played_last
# 0            2012.0           2023.0

# %%
from pybaseball import plot_teams, team_batting

data = team_batting(2023)

plot_teams(data, "HR", "BB")

# %%
data
# Out:
#     teamIDfg  Season Team  Age     G    AB    PA     H   1B   2B  ...  maxEV  \
# 0         16    2023  ATL   29  2030  4992  5574  1372  822  250  ...  121.2
# 1         22    2023  LAD   29  2154  4905  5647  1266  746  277  ...  112.7
# 2         13    2023  TEX   29  2037  5002  5624  1333  811  303  ...  115.2
# 3         12    2023  TBR   28  2101  4932  5531  1274  795  248  ...  114.5
# 4         26    2023  PHI   28  2084  4980  5577  1290  798  270  ...  115.7
# 5         21    2023  HOU   29  2050  5019  5635  1302  838  250  ...  116.0
# 6          3    2023  BOS   29  2139  5000  5557  1315  811  315  ...  115.0
# 7         14    2023  TOR   29  2147  4972  5564  1290  843  265  ...  116.7
# 8         28    2023  STL   28  2051  4958  5567  1256  810  236  ...  117.5
# 9          2    2023  BAL   28  2158  4909  5475  1273  798  280  ...  114.6
# 10        17    2023  CHC   28  2082  4943  5575  1255  815  239  ...  114.6
# ...

# %%
from pybaseball import statcast_batter

# %%
data = statcast_batter('2018-04-01', '2023-09-10', player_id = 660271)
# Out:
# Gathering Player Data

# %%
data.keys()
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
# ...

# %%
data['game_type']
# Out:
# 0        R
# 1        R
# 2        R
# 3        R
# 4        R
#         ..
# 11612    R
# 11613    R
# 11614    R
# 11615    R
# 11616    R
# Name: game_type, Length: 11617, dtype: object

# %%
data['p_throws']
# Out:
# 0        L
# 1        L
# 2        L
# 3        L
# 4        L
#         ..
# 11612    R
# 11613    R
# 11614    R
# 11615    R
# 11616    R
# Name: p_throws, Length: 11617, dtype: object
